# %%
# Tasks
# 1. data extraction, column naming, value counts, summary stats, 
# 2. load full data (partial columns, full columns, random sample)
# 3. nlp on body, date counts, usr and msg distinct counts, skip
# 4. figure out what the max col usage is for, and what does each of the filler columns mean
# 5. json extraction

# %%
PATH  = '/Users/pranjal/Downloads/part-00000-tid-7073521145656742331-3e06173f-1926-41aa-b3b7-847006329acc-4624-1-c000.vhbbdAj4.csv'
PATH2 = '/Users/pranjal/Downloads/part-00000-tid-7073521145656742331-3e06173f-1926-41aa-b3b7-847006329acc-4624-1-c000.Tduu8OeG.csv.part'
column_names = ['userid', 'event', 'msgid', 'cts', 'body']
import pandas as pd
import random
p = 0.05
df = pd.read_csv(PATH, 
                 error_bad_lines = False, 
                 names = column_names, 
                 nrows = 1460955,
                 skiprows=lambda i: i>0 and random.random() > p
                ) #skiprows = 460953, nrows = 200000)

df.head()

# %%
df.head()
# Out:
#                                  userid                 event  \
# 0                                UserId      IntegrationEvent
# 1  02542fb7-9ee9-49f9-b17f-e7f6c841c9bb          UserSignedIn
# 2  02542fb7-9ee9-49f9-b17f-e7f6c841c9bb          UserSignedIn
# 3  02542fb7-9ee9-49f9-b17f-e7f6c841c9bb          UserSignedIn
# 4  02650cc5-b4da-483a-96cc-4b6a5119a808  TransactionConfirmed
#
#                                   msgid                       cts  \
# 0                             MessageId           CreationDateUtc
# 1  e1a14dbe-adc8-4eb9-b043-fd7315e9234f  2021-09-30T12:51:36.000Z
# 2  4119096b-b521-4943-9a42-abb09e7dd617  2021-11-04T11:20:56.000Z
# 3  239394f5-489c-4c88-9d9c-87ab7c0180d7  2021-09-28T09:19:06.000Z
# 4  6ab71768-d3d3-4144-96b9-7c1fe581f1eb  2022-06-01T05:31:19.000Z
#
#                                                 body
# 0                                        ClearedBody
# 1  {\deviceCode\": \"a7ebd2ee-72aa-45fc-9825-246b...
# ...

# %%
PATH  = '/Users/pranjal/Downloads/part-00000-tid-7073521145656742331-3e06173f-1926-41aa-b3b7-847006329acc-4624-1-c000.vhbbdAj4.csv'
PATH2 = '/Users/pranjal/Downloads/part-00000-tid-7073521145656742331-3e06173f-1926-41aa-b3b7-847006329acc-4624-1-c000.Tduu8OeG.csv.part'
column_names = ['userid', 'event', 'msgid', 'cts', 'body'] + list(range(1,17))
import pandas as pd
import random
p = 0.05
df = pd.read_csv(PATH, 
                 error_bad_lines = False, 
                 names = column_names, 
                 nrows = 1460955,
                 skiprows=lambda i: i>0 and random.random() > p
                ) #skiprows = 460953, nrows = 200000)
# Out:
# /usr/local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (16,17,18,19,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df.head(5)
# Out:
#                                  userid             event  \
# 0                                UserId  IntegrationEvent
# 1  02542fb7-9ee9-49f9-b17f-e7f6c841c9bb      UserSignedIn
# 2  02542fb7-9ee9-49f9-b17f-e7f6c841c9bb      UserSignedIn
# 3  02650cc5-b4da-483a-96cc-4b6a5119a808      UserSignedIn
# 4  02650cc5-b4da-483a-96cc-4b6a5119a808      UserSignedIn
#
#                                   msgid                       cts  \
# 0                             MessageId           CreationDateUtc
# 1  4119096b-b521-4943-9a42-abb09e7dd617  2021-11-04T11:20:56.000Z
# 2  239394f5-489c-4c88-9d9c-87ab7c0180d7  2021-09-28T09:19:06.000Z
# 3  4c8a3fff-7ba5-469f-8737-3fe1040147a9  2022-02-08T13:05:37.000Z
# 4  48afab0f-6e83-4198-afb7-7e4ba864e16a  2022-02-08T13:14:41.000Z
#
#                                                 body  \
# 0                                        ClearedBody
# 1  {\deviceCode\": \"a44e3f40-511c-452a-99c8-7be3...
# ...

# %%
events = df.event.value_counts().index.tolist()

# %%
df_full = df[df.iloc[:,20].notna()]
df_full.head()
# Out:
#                                      userid                  event  \
# 79367  3a7a1743-c494-47d9-8932-dacd519c4b26  SubscriptionActivated
#
#                                       msgid                       cts  \
# 79367  fc45ad04-8250-48dc-b896-4cca8636708c  2022-06-10T16:26:55.000Z
#
#                             body                       1  \
# 79367  {\activationAmount\": 0.0   \"activationGems\": 0
#
#                                     2  \
# 79367   \"product\": \"Friend4Life2\"
#
#                                                        3               4  \
# 79367   \"includedServices\": [\"AdvancedExpensesAnal...   \"Budgeting\"
#
#                           5  ...             7  \
# 79367   \"CO2Compensation\"  ...   \"Mooney\"]
#
#                                                        8  \
# 79367   \"actualProductsSet\": [{\"product\": \"Advan...
#
#                                    9                                   10  \
# ...

# %%
print(df.head().to_string())
# Out:
#                                  userid                 event                                 msgid                       cts                                                      body
# 0                                UserId      IntegrationEvent                             MessageId           CreationDateUtc                                               ClearedBody
# 1  02542fb7-9ee9-49f9-b17f-e7f6c841c9bb          UserSignedIn  e1a14dbe-adc8-4eb9-b043-fd7315e9234f  2021-09-30T12:51:36.000Z  {\deviceCode\": \"a7ebd2ee-72aa-45fc-9825-246bc55eabdf\"
# 2  02542fb7-9ee9-49f9-b17f-e7f6c841c9bb          UserSignedIn  4119096b-b521-4943-9a42-abb09e7dd617  2021-11-04T11:20:56.000Z  {\deviceCode\": \"a44e3f40-511c-452a-99c8-7be335680c9a\"
# 3  02542fb7-9ee9-49f9-b17f-e7f6c841c9bb          UserSignedIn  239394f5-489c-4c88-9d9c-87ab7c0180d7  2021-09-28T09:19:06.000Z  {\deviceCode\": \"a7ebd2ee-72aa-45fc-9825-246bc55eabdf\"
# ...

# %%
import json
df["body"][2].apply(json.loads)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-7d0cdbda0f0e> in <module>
#       1 import json
# ----> 2 df["body"][2].apply(json.loads)
#
# AttributeError: 'str' object has no attribute 'apply'

# %%
df["body"][2]
# Out:
# '{\\deviceCode\\": \\"a44e3f40-511c-452a-99c8-7be335680c9a\\"'

# %%
json.loads(df["body"][2])
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# <ipython-input-114-2da3855c7be8> in <module>
# ----> 1 json.loads(df["body"][2])
#
# /usr/local/Cellar/python@3.8/3.8.8_1/Frameworks/Python.framework/Versions/3.8/lib/python3.8/json/__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     355             parse_int is None and parse_float is None and
#     356             parse_constant is None and object_pairs_hook is None and not kw):
# --> 357         return _default_decoder.decode(s)
#     358     if cls is None:
#     359         cls = JSONDecoder
#
# /usr/local/Cellar/python@3.8/3.8.8_1/Frameworks/Python.framework/Versions/3.8/lib/python3.8/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
# ...
